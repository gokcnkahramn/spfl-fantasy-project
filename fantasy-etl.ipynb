# %%
import requests
from typing import Optional, Dict, Any, List
from dataclasses import dataclass
import pandas as pd
from functools import lru_cache

BASE_URL = "https://fantasy.spfl.co.uk"
SEARCH_ENDPOINT = f"{BASE_URL}/v1/private/searchjoueurs?lg=en"
STATS_ENDPOINT = f"{BASE_URL}/v1/private/statsjoueur?lg=en"

@dataclass
class Config:
    AUTH_TOKEN: str = "Token enter_your_auth_token_here"
    X_ACCESS_KEY: str = "enter_your_access_key_here"
    USER_AGENT: str = "enter_your_user_agent_here"

class SPFLClient:
    def __init__(self, config: Config):
        self.session = requests.Session()
        self.session.headers.update({
            "Accept": "application/json",
            "Content-Type": "application/json",
            "Authorization": config.AUTH_TOKEN,
            "x-access-key": config.X_ACCESS_KEY,
            "Origin": BASE_URL,
            "Referer": f"{BASE_URL}/",
            "User-Agent": config.USER_AGENT,
            "X-Requested-With": "XMLHttpRequest",
        })
    
    def _make_request(self, url: str, payload: Dict) -> Dict:
        try:
            print(f"\nSending request to {url}")
            response = self.session.post(url, json=payload, timeout=30)
            response.raise_for_status()
            
            # First try to get the raw text
            response_text = response.text
            if not response_text.strip():
                raise ValueError("Empty response from server")
                
            # Try to parse as JSON
            try:
                data = response.json()
                if not isinstance(data, dict):
                    print(f"Warning: Expected dict but got {type(data).__name__}")
                    data = {"data": data}  # Wrap in a dict if needed
                return data
                
            except ValueError as e:
                print(f"Error parsing JSON: {e}")
                print(f"Response text: {response_text[:200]}...")
                raise ValueError(f"Invalid JSON response: {str(e)}")
                
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {str(e)}")
            if hasattr(e, 'response') and e.response is not None:
                print(f"Response status: {e.response.status_code}")
                print(f"Response text: {getattr(e.response, 'text', '')[:200]}...")
            raise

class PlayerService:
    POSITION_MAP = {
        "lib_gardien": "GK",
        "lib_defenseur": "DEF",
        "lib_milieu": "MID",
        "lib_attaquant": "FWD",
    }
    
    def __init__(self, client: SPFLClient):
        self.client = client
    
    def _map_position(self, position: Optional[str]) -> str:
        if not position:
            return "UNK"
        position = position.replace("_court", "")
        return self.POSITION_MAP.get(position, position)
    
    def _normalize_player(self, player: Dict) -> Dict:
        club = player.get("club", {}).get("nom", "Unknown") if isinstance(player.get("club"), dict) else player.get("club", "Unknown")
        return {
            "id": player.get("id"),
            "name": player.get("nom"),
            "full_name": player.get("nomcomplet") or player.get("display_name") or player.get("full_name"),
            "position_code": player.get("position"),
            "position": self._map_position(player.get("position")),
            "club": club,
            "value": player.get("valeur"),
            "team_trg": player.get("trgclub"),
        }
    
    def get_players(self, page_size: int = 10, page_number: int = 1) -> List[Dict]:
        """
        Fetch players for a specific page.
        
        Args:
            page_size: Number of players per page
            page_number: Page number to fetch (1-based)
            
        Returns:
            List of player dictionaries
        """
        # Main payload with proper pagination
        payload = {
            "filters": {
                "budget_ok": False,
                "club": "",
                "dreamteam": False,
                "engage": False,
                "idj": "4",
                "loadSelect": 0,
                "nom": "",
                "partant": False,
                "position": "",
                "quota": "",
                "valeur_max": 20,
                "pageIndex": page_number - 1,  # 0-based index for the API
                "pageSize": page_size,
                "searchonly": 1
            }
        }
        
        try:
            print(f"Fetching page {page_number}...")
            data = self.client._make_request(SEARCH_ENDPOINT, payload)
            
            # Extract players from response
            players = []
            if isinstance(data, dict):
                players = data.get("joueurs", [])
                if not players and "data" in data and isinstance(data["data"], dict):
                    players = data["data"].get("joueurs", [])
            
            if not players:
                print(f"No players found on page {page_number}")
                return []
                
            print(f"Found {len(players)} players on page {page_number}")
            
            # Process and return players
            result = []
            for player in players:
                if isinstance(player, dict) and player.get("id"):
                    result.append(self._normalize_player(player))
            
            return result
                
        except Exception as e:
            print(f"Error fetching page {page_number}: {e}")
            return []

def save_players(players: List[Dict], format: str = "csv") -> None:
    """Save players data to file in specified format."""
    if not players:
        print("No players data to save.")
        return
        
    df = pd.DataFrame(players)
    filename = f"players.{format.lower()}"
    
    try:
        if format.lower() == "csv":
            df.to_csv(filename, index=False, encoding="utf-8")
        elif format.lower() == "parquet":
            df.to_parquet(filename, index=False)
        else:
            raise ValueError(f"Unsupported format: {format}")
        print(f"Successfully saved {len(players)} players to {filename}")
    except Exception as e:
        print(f"Error saving {filename}: {e}")

def main():
    config = Config()
    client = SPFLClient(config)
    player_service = PlayerService(client)
    
    all_players = []
    seen_ids = set()
    
    # Process each page from 1 to 35
    for page in range(1, 36):
        print(f"\n=== Processing Page {page} ===")
        try:
            # Get players for the current page
            players = player_service.get_players(page_size=10, page_number=page)
            
            if not players:
                print(f"No more players found on page {page}, stopping...")
                break
                
            # Add only new players
            new_players = []
            for player in players:
                player_id = player.get("id")
                if player_id and player_id not in seen_ids:
                    seen_ids.add(player_id)
                    all_players.append(player)
                    new_players.append(player)
            
            print(f"Added {len(new_players)} new players from page {page}")
            
            # Save after each page to prevent data loss
            if all_players:
                save_players(all_players, "csv")
                save_players(all_players, "parquet")
                
            print(f"Page {page} completed. Total unique players so far: {len(all_players)}")
            
            # Small delay to be nice to the server
            import time
            time.sleep(1)
            
        except Exception as e:
            print(f"Error processing page {page}: {e}")
            continue
    
    print(f"\n=== Final Results ===")
    print(f"Total unique players fetched: {len(all_players)}")
    print(f"Data saved to players.csv and players.parquet")

if __name__ == "__main__":
    main()
# Out:
# === Processing Page 1 ===
# Fetching page 1...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 1
# Added 10 new players from page 1
# Successfully saved 10 players to players.csv
# Successfully saved 10 players to players.parquet
# Page 1 completed. Total unique players so far: 10
#
# === Processing Page 2 ===
# Fetching page 2...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 2
# Added 10 new players from page 2
# Successfully saved 20 players to players.csv
# Successfully saved 20 players to players.parquet
# Page 2 completed. Total unique players so far: 20
#
# === Processing Page 3 ===
# Fetching page 3...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 3
# Added 10 new players from page 3
# Successfully saved 30 players to players.csv
# Successfully saved 30 players to players.parquet
# Page 3 completed. Total unique players so far: 30
#
# === Processing Page 4 ===
# Fetching page 4...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 4
# Added 10 new players from page 4
# Successfully saved 40 players to players.csv
# Successfully saved 40 players to players.parquet
# Page 4 completed. Total unique players so far: 40
#
# === Processing Page 5 ===
# Fetching page 5...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 5
# Added 10 new players from page 5
# Successfully saved 50 players to players.csv
# Successfully saved 50 players to players.parquet
# Page 5 completed. Total unique players so far: 50
#
# === Processing Page 6 ===
# Fetching page 6...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 6
# Added 10 new players from page 6
# Successfully saved 60 players to players.csv
# Successfully saved 60 players to players.parquet
# Page 6 completed. Total unique players so far: 60
#
# === Processing Page 7 ===
# Fetching page 7...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 7
# Added 10 new players from page 7
# Successfully saved 70 players to players.csv
# Successfully saved 70 players to players.parquet
# Page 7 completed. Total unique players so far: 70
#
# === Processing Page 8 ===
# Fetching page 8...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 8
# Added 10 new players from page 8
# Successfully saved 80 players to players.csv
# Successfully saved 80 players to players.parquet
# Page 8 completed. Total unique players so far: 80
#
# === Processing Page 9 ===
# Fetching page 9...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 9
# Added 10 new players from page 9
# Successfully saved 90 players to players.csv
# Successfully saved 90 players to players.parquet
# Page 9 completed. Total unique players so far: 90
#
# === Processing Page 10 ===
# Fetching page 10...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 10
# Added 10 new players from page 10
# Successfully saved 100 players to players.csv
# Successfully saved 100 players to players.parquet
# Page 10 completed. Total unique players so far: 100
#
# === Processing Page 11 ===
# Fetching page 11...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 11
# Added 10 new players from page 11
# Successfully saved 110 players to players.csv
# Successfully saved 110 players to players.parquet
# Page 11 completed. Total unique players so far: 110
#
# === Processing Page 12 ===
# Fetching page 12...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 12
# Added 10 new players from page 12
# Successfully saved 120 players to players.csv
# Successfully saved 120 players to players.parquet
# Page 12 completed. Total unique players so far: 120
#
# === Processing Page 13 ===
# Fetching page 13...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 13
# Added 10 new players from page 13
# Successfully saved 130 players to players.csv
# Successfully saved 130 players to players.parquet
# Page 13 completed. Total unique players so far: 130
#
# === Processing Page 14 ===
# Fetching page 14...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 14
# Added 10 new players from page 14
# Successfully saved 140 players to players.csv
# Successfully saved 140 players to players.parquet
# Page 14 completed. Total unique players so far: 140
#
# === Processing Page 15 ===
# Fetching page 15...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 15
# Added 10 new players from page 15
# Successfully saved 150 players to players.csv
# Successfully saved 150 players to players.parquet
# Page 15 completed. Total unique players so far: 150
#
# === Processing Page 16 ===
# Fetching page 16...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 16
# Added 10 new players from page 16
# Successfully saved 160 players to players.csv
# Successfully saved 160 players to players.parquet
# Page 16 completed. Total unique players so far: 160
#
# === Processing Page 17 ===
# Fetching page 17...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 17
# Added 10 new players from page 17
# Successfully saved 170 players to players.csv
# Successfully saved 170 players to players.parquet
# Page 17 completed. Total unique players so far: 170
#
# === Processing Page 18 ===
# Fetching page 18...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 18
# Added 10 new players from page 18
# Successfully saved 180 players to players.csv
# Successfully saved 180 players to players.parquet
# Page 18 completed. Total unique players so far: 180
#
# === Processing Page 19 ===
# Fetching page 19...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 19
# Added 10 new players from page 19
# Successfully saved 190 players to players.csv
# Successfully saved 190 players to players.parquet
# Page 19 completed. Total unique players so far: 190
#
# === Processing Page 20 ===
# Fetching page 20...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 20
# Added 10 new players from page 20
# Successfully saved 200 players to players.csv
# Successfully saved 200 players to players.parquet
# Page 20 completed. Total unique players so far: 200
#
# === Processing Page 21 ===
# Fetching page 21...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 21
# Added 10 new players from page 21
# Successfully saved 210 players to players.csv
# Successfully saved 210 players to players.parquet
# Page 21 completed. Total unique players so far: 210
#
# === Processing Page 22 ===
# Fetching page 22...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 22
# Added 10 new players from page 22
# Successfully saved 220 players to players.csv
# Successfully saved 220 players to players.parquet
# Page 22 completed. Total unique players so far: 220
#
# === Processing Page 23 ===
# Fetching page 23...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 23
# Added 10 new players from page 23
# Successfully saved 230 players to players.csv
# Successfully saved 230 players to players.parquet
# Page 23 completed. Total unique players so far: 230
#
# === Processing Page 24 ===
# Fetching page 24...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 24
# Added 10 new players from page 24
# Successfully saved 240 players to players.csv
# Successfully saved 240 players to players.parquet
# Page 24 completed. Total unique players so far: 240
#
# === Processing Page 25 ===
# Fetching page 25...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 25
# Added 10 new players from page 25
# Successfully saved 250 players to players.csv
# Successfully saved 250 players to players.parquet
# Page 25 completed. Total unique players so far: 250
#
# === Processing Page 26 ===
# Fetching page 26...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 26
# Added 10 new players from page 26
# Successfully saved 260 players to players.csv
# Successfully saved 260 players to players.parquet
# Page 26 completed. Total unique players so far: 260
#
# === Processing Page 27 ===
# Fetching page 27...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 27
# Added 10 new players from page 27
# Successfully saved 270 players to players.csv
# Successfully saved 270 players to players.parquet
# Page 27 completed. Total unique players so far: 270
#
# === Processing Page 28 ===
# Fetching page 28...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 28
# Added 10 new players from page 28
# Successfully saved 280 players to players.csv
# Successfully saved 280 players to players.parquet
# Page 28 completed. Total unique players so far: 280
#
# === Processing Page 29 ===
# Fetching page 29...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 29
# Added 10 new players from page 29
# Successfully saved 290 players to players.csv
# Successfully saved 290 players to players.parquet
# Page 29 completed. Total unique players so far: 290
#
# === Processing Page 30 ===
# Fetching page 30...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 10 players on page 30
# Added 10 new players from page 30
# Successfully saved 300 players to players.csv
# Successfully saved 300 players to players.parquet
# Page 30 completed. Total unique players so far: 300
#
# === Processing Page 31 ===
# Fetching page 31...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# Found 5 players on page 31
# Added 5 new players from page 31
# Successfully saved 305 players to players.csv
# Successfully saved 305 players to players.parquet
# Page 31 completed. Total unique players so far: 305
#
# === Processing Page 32 ===
# Fetching page 32...
#
# Sending request to https://fantasy.spfl.co.uk/v1/private/searchjoueurs?lg=en
# No players found on page 32
# No more players found on page 32, stopping...
#
# === Final Results ===
# Total unique players fetched: 305
# Data saved to players.csv and players.parquet

# %%
import requests
import csv
import time
import json
from datetime import datetime

# API Configuration
url = "https://fantasy.spfl.co.uk/v1/private/statsjoueur?lg=en"
headers = {
    "Content-Type": "application/json",
    "Authorization": "Token enter_your_auth_token_here",
    "x-access-key": "enter_your_access_key_here"
}

def process_player_data(player_id, player_data):
    """Process player data into a flattened dictionary"""
    if not player_data:
        return None
    
    # Basic player info
    stats = {
        'player_id': player_id,
        'matches_played': player_data.get('nbmatchs', 0)
    }
    
    # Process individual statistics
    for stat in player_data.get('stats_individuelles', []):
        stat_name = stat['libelle'].lower().replace(' ', '_')
        stats[f'total_{stat_name}'] = stat.get('total', 0)
        stats[f'avg_{stat_name}'] = stat.get('moy', 0)
    
    # Process points history
    for i, point in enumerate(player_data.get('points_marques', []), 1):
        stats[f'gameweek_{i}_points'] = point.get('nb_points', 0)
    
    # Process value history
    values = player_data.get('valeur_footballeur', [])
    if values:
        stats['current_value'] = values[-1]
    
    return stats

def save_to_csv(players_data, filename='player_stats.csv'):
    """Save processed player data to CSV"""
    if not players_data:
        print("No data to save")
        return
    
    # Get all unique keys from all players
    all_keys = set()
    for player in players_data:
        all_keys.update(player.keys())
    
    # Sort keys for consistent column order
    fieldnames = sorted(all_keys)
    
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(players_data)
    
    print(f"\nData saved to {filename}")

# Read player IDs from CSV
player_ids = []
with open('players.csv', 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        player_ids.append(row['id'])

# Fetch and process data for each player
all_players_data = []
for player_id in player_ids:
    payload = {
        "credentials": {
            "idj": "4",
            "idf": int(player_id),
            "detail": True
        }
    }
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        print(f"Processing Player ID: {player_id} - Status: {response.status_code}")
        
        if response.status_code == 200:
            player_data = response.json()
            processed_data = process_player_data(player_id, player_data)
            if processed_data:
                all_players_data.append(processed_data)
        
        time.sleep(1)  # Be nice to the API
        
    except Exception as e:
        print(f"Error processing player ID {player_id}: {str(e)}")

# Save all data to CSV
save_to_csv(all_players_data)
# Out:
# Processing Player ID: 62 - Status: 200
# Processing Player ID: 241 - Status: 200
# Processing Player ID: 552 - Status: 200
# Processing Player ID: 479 - Status: 200
# Processing Player ID: 824 - Status: 200
# Processing Player ID: 514 - Status: 200
# Processing Player ID: 50 - Status: 200
# Processing Player ID: 949 - Status: 200
# Processing Player ID: 947 - Status: 200
# Processing Player ID: 579 - Status: 200
# Processing Player ID: 808 - Status: 200
# Processing Player ID: 706 - Status: 200
# Processing Player ID: 782 - Status: 200
# Processing Player ID: 435 - Status: 200
# Processing Player ID: 398 - Status: 200
# Processing Player ID: 51 - Status: 200
# Processing Player ID: 711 - Status: 200
# Processing Player ID: 505 - Status: 200
# Processing Player ID: 431 - Status: 200
# Processing Player ID: 60 - Status: 200
# Processing Player ID: 550 - Status: 200
# Processing Player ID: 1025 - Status: 200
# Processing Player ID: 815 - Status: 200
# Processing Player ID: 989 - Status: 200
# Processing Player ID: 566 - Status: 200
# Processing Player ID: 1003 - Status: 200
# Processing Player ID: 35 - Status: 200
# Processing Player ID: 4 - Status: 200
# Processing Player ID: 980 - Status: 200
# Processing Player ID: 810 - Status: 200
# Processing Player ID: 742 - Status: 200
# Processing Player ID: 1019 - Status: 200
# Processing Player ID: 823 - Status: 200
# Processing Player ID: 654 - Status: 200
# Processing Player ID: 619 - Status: 200
# Processing Player ID: 486 - Status: 200
# Processing Player ID: 722 - Status: 200
# Processing Player ID: 358 - Status: 200
# Processing Player ID: 222 - Status: 200
# Processing Player ID: 39 - Status: 200
# Processing Player ID: 971 - Status: 200
# Processing Player ID: 340 - Status: 200
# Processing Player ID: 240 - Status: 200
# Processing Player ID: 221 - Status: 200
# Processing Player ID: 1000 - Status: 200
# Processing Player ID: 432 - Status: 200
# Processing Player ID: 150 - Status: 200
# Processing Player ID: 53 - Status: 200
# Processing Player ID: 1022 - Status: 200
# Processing Player ID: 905 - Status: 200
# Processing Player ID: 812 - Status: 200
# Processing Player ID: 532 - Status: 200
# Processing Player ID: 493 - Status: 200
# Processing Player ID: 198 - Status: 200
# Processing Player ID: 961 - Status: 200
# Processing Player ID: 902 - Status: 200
# Processing Player ID: 609 - Status: 200
# Processing Player ID: 557 - Status: 200
# Processing Player ID: 346 - Status: 200
# Processing Player ID: 135 - Status: 200
# Processing Player ID: 962 - Status: 200
# Processing Player ID: 180 - Status: 200
# Processing Player ID: 1035 - Status: 200
# Processing Player ID: 999 - Status: 200
# Processing Player ID: 944 - Status: 200
# Processing Player ID: 757 - Status: 200
# Processing Player ID: 710 - Status: 200
# Processing Player ID: 1034 - Status: 200
# Processing Player ID: 913 - Status: 200
# Processing Player ID: 265 - Status: 200
# Processing Player ID: 1024 - Status: 200
# Processing Player ID: 959 - Status: 200
# Processing Player ID: 829 - Status: 200
# Processing Player ID: 768 - Status: 200
# Processing Player ID: 719 - Status: 200
# Processing Player ID: 613 - Status: 200
# Processing Player ID: 341 - Status: 200
# Processing Player ID: 115 - Status: 200
# Processing Player ID: 18 - Status: 200
# Processing Player ID: 915 - Status: 200
# Processing Player ID: 849 - Status: 200
# Processing Player ID: 781 - Status: 200
# Processing Player ID: 630 - Status: 200
# Processing Player ID: 577 - Status: 200
# Processing Player ID: 434 - Status: 200
# Processing Player ID: 379 - Status: 200
# Processing Player ID: 311 - Status: 200
# Processing Player ID: 111 - Status: 200
# Processing Player ID: 21 - Status: 200
# Processing Player ID: 973 - Status: 200
# Processing Player ID: 554 - Status: 200
# Processing Player ID: 190 - Status: 200
# Processing Player ID: 764 - Status: 200
# Processing Player ID: 143 - Status: 200
# Processing Player ID: 1036 - Status: 200
# Processing Player ID: 997 - Status: 200
# Processing Player ID: 995 - Status: 200
# Processing Player ID: 936 - Status: 200
# Processing Player ID: 537 - Status: 200
# Processing Player ID: 171 - Status: 200
# Processing Player ID: 61 - Status: 200
# Processing Player ID: 1016 - Status: 200
# Processing Player ID: 992 - Status: 200
# Processing Player ID: 974 - Status: 200
# Processing Player ID: 946 - Status: 200
# Processing Player ID: 939 - Status: 200
# Processing Player ID: 935 - Status: 200
# Processing Player ID: 809 - Status: 200
# Processing Player ID: 733 - Status: 200
# Processing Player ID: 689 - Status: 200
# Processing Player ID: 592 - Status: 200
# Processing Player ID: 349 - Status: 200
# Processing Player ID: 139 - Status: 200
# Processing Player ID: 72 - Status: 200
# Processing Player ID: 1013 - Status: 200
# Processing Player ID: 1011 - Status: 200
# Processing Player ID: 1009 - Status: 200
# Processing Player ID: 1006 - Status: 200
# Processing Player ID: 956 - Status: 200
# Processing Player ID: 889 - Status: 200
# Processing Player ID: 886 - Status: 200
# Processing Player ID: 850 - Status: 200
# Processing Player ID: 830 - Status: 200
# Processing Player ID: 797 - Status: 200
# Processing Player ID: 604 - Status: 200
# Processing Player ID: 551 - Status: 200
# Processing Player ID: 375 - Status: 200
# Processing Player ID: 140 - Status: 200
# Processing Player ID: 114 - Status: 200
# Processing Player ID: 25 - Status: 200
# Processing Player ID: 861 - Status: 200
# Processing Player ID: 840 - Status: 200
# Processing Player ID: 778 - Status: 200
# Processing Player ID: 587 - Status: 200
# Processing Player ID: 576 - Status: 200
# Processing Player ID: 563 - Status: 200
# Processing Player ID: 1033 - Status: 200
# Processing Player ID: 1027 - Status: 200
# Processing Player ID: 814 - Status: 200
# Processing Player ID: 15 - Status: 200
# Processing Player ID: 1032 - Status: 200
# Processing Player ID: 951 - Status: 200
# Processing Player ID: 933 - Status: 200
# Processing Player ID: 83 - Status: 200
# Processing Player ID: 1029 - Status: 200
# Processing Player ID: 1026 - Status: 200
# Processing Player ID: 1023 - Status: 200
# Processing Player ID: 1021 - Status: 200
# Processing Player ID: 1018 - Status: 200
# Processing Player ID: 996 - Status: 200
# Processing Player ID: 986 - Status: 200
# Processing Player ID: 970 - Status: 200
# Processing Player ID: 963 - Status: 200
# Processing Player ID: 928 - Status: 200
# Processing Player ID: 904 - Status: 200
# Processing Player ID: 880 - Status: 200
# Processing Player ID: 854 - Status: 200
# Processing Player ID: 789 - Status: 200
# Processing Player ID: 784 - Status: 200
# Processing Player ID: 756 - Status: 200
# Processing Player ID: 728 - Status: 200
# Processing Player ID: 286 - Status: 200
# Processing Player ID: 142 - Status: 200
# Processing Player ID: 1037 - Status: 200
# Processing Player ID: 968 - Status: 200
# Processing Player ID: 948 - Status: 200
# Processing Player ID: 940 - Status: 200
# Processing Player ID: 883 - Status: 200
# Processing Player ID: 875 - Status: 200
# Processing Player ID: 874 - Status: 200
# Processing Player ID: 774 - Status: 200
# Processing Player ID: 755 - Status: 200
# Processing Player ID: 703 - Status: 200
# Processing Player ID: 646 - Status: 200
# Processing Player ID: 558 - Status: 200
# Processing Player ID: 547 - Status: 200
# Processing Player ID: 376 - Status: 200
# Processing Player ID: 352 - Status: 200
# Processing Player ID: 334 - Status: 200
# Processing Player ID: 101 - Status: 200
# Processing Player ID: 40 - Status: 200
# Processing Player ID: 979 - Status: 200
# Processing Player ID: 969 - Status: 200
# Processing Player ID: 960 - Status: 200
# Processing Player ID: 759 - Status: 200
# Processing Player ID: 737 - Status: 200
# Processing Player ID: 578 - Status: 200
# Processing Player ID: 368 - Status: 200
# Processing Player ID: 337 - Status: 200
# Processing Player ID: 308 - Status: 200
# Processing Player ID: 215 - Status: 200
# Processing Player ID: 169 - Status: 200
# Processing Player ID: 967 - Status: 200
# Processing Player ID: 926 - Status: 200
# Processing Player ID: 910 - Status: 200
# Processing Player ID: 845 - Status: 200
# Processing Player ID: 811 - Status: 200
# Processing Player ID: 460 - Status: 200
# Processing Player ID: 442 - Status: 200
# Processing Player ID: 156 - Status: 200
# Processing Player ID: 1010 - Status: 200
# Processing Player ID: 987 - Status: 200
# Processing Player ID: 941 - Status: 200
# Processing Player ID: 879 - Status: 200
# Processing Player ID: 727 - Status: 200
# Processing Player ID: 405 - Status: 200
# Processing Player ID: 191 - Status: 200
# Processing Player ID: 104 - Status: 200
# Processing Player ID: 1008 - Status: 200
# Processing Player ID: 988 - Status: 200
# Processing Player ID: 975 - Status: 200
# Processing Player ID: 972 - Status: 200
# Processing Player ID: 958 - Status: 200
# Processing Player ID: 943 - Status: 200
# Processing Player ID: 942 - Status: 200
# Processing Player ID: 934 - Status: 200
# Processing Player ID: 932 - Status: 200
# Processing Player ID: 927 - Status: 200
# Processing Player ID: 925 - Status: 200
# Processing Player ID: 922 - Status: 200
# Processing Player ID: 914 - Status: 200
# Processing Player ID: 901 - Status: 200
# Processing Player ID: 795 - Status: 200
# Processing Player ID: 767 - Status: 200
# Processing Player ID: 740 - Status: 200
# Processing Player ID: 696 - Status: 200
# Processing Player ID: 615 - Status: 200
# Processing Player ID: 610 - Status: 200
# Processing Player ID: 472 - Status: 200
# Processing Player ID: 179 - Status: 200
# Processing Player ID: 88 - Status: 200
# Processing Player ID: 16 - Status: 200
# Processing Player ID: 1015 - Status: 200
# Processing Player ID: 998 - Status: 200
# Processing Player ID: 993 - Status: 200
# Processing Player ID: 976 - Status: 200
# Processing Player ID: 966 - Status: 200
# Processing Player ID: 950 - Status: 200
# Processing Player ID: 930 - Status: 200
# Processing Player ID: 765 - Status: 200
# Processing Player ID: 745 - Status: 200
# Processing Player ID: 741 - Status: 200
# Processing Player ID: 675 - Status: 200
# Processing Player ID: 673 - Status: 200
# Processing Player ID: 636 - Status: 200
# Processing Player ID: 572 - Status: 200
# Processing Player ID: 568 - Status: 200
# Processing Player ID: 544 - Status: 200
# Processing Player ID: 522 - Status: 200
# Processing Player ID: 515 - Status: 200
# Processing Player ID: 451 - Status: 200
# Processing Player ID: 438 - Status: 200
# Processing Player ID: 403 - Status: 200
# Processing Player ID: 329 - Status: 200
# Processing Player ID: 323 - Status: 200
# Processing Player ID: 304 - Status: 200
# Processing Player ID: 219 - Status: 200
# Processing Player ID: 208 - Status: 200
# Processing Player ID: 203 - Status: 200
# Processing Player ID: 195 - Status: 200
# Processing Player ID: 185 - Status: 200
# Processing Player ID: 173 - Status: 200
# Processing Player ID: 163 - Status: 200
# Processing Player ID: 137 - Status: 200
# Processing Player ID: 121 - Status: 200
# Processing Player ID: 97 - Status: 200
# Processing Player ID: 87 - Status: 200
# Processing Player ID: 24 - Status: 200
# Processing Player ID: 6 - Status: 200
# Processing Player ID: 1030 - Status: 200
# Processing Player ID: 991 - Status: 200
# Processing Player ID: 965 - Status: 200
# Processing Player ID: 955 - Status: 200
# Processing Player ID: 953 - Status: 200
# Processing Player ID: 952 - Status: 200
# Processing Player ID: 924 - Status: 200
# Processing Player ID: 859 - Status: 200
# Processing Player ID: 775 - Status: 200
# Processing Player ID: 760 - Status: 200
# Processing Player ID: 595 - Status: 200
# Processing Player ID: 482 - Status: 200
# Processing Player ID: 70 - Status: 200
# Processing Player ID: 17 - Status: 200
# Processing Player ID: 954 - Status: 200
# Processing Player ID: 909 - Status: 200
# Processing Player ID: 906 - Status: 200
# Processing Player ID: 983 - Status: 200
# Processing Player ID: 981 - Status: 200
# Processing Player ID: 891 - Status: 200
# Processing Player ID: 799 - Status: 200
# Processing Player ID: 541 - Status: 200
# Processing Player ID: 402 - Status: 200
# Processing Player ID: 945 - Status: 200
# Processing Player ID: 923 - Status: 200
# Processing Player ID: 634 - Status: 200
# Processing Player ID: 127 - Status: 200
# Processing Player ID: 990 - Status: 200
# Processing Player ID: 770 - Status: 200
# Processing Player ID: 758 - Status: 200
# Processing Player ID: 542 - Status: 200
# Processing Player ID: 535 - Status: 200
# Processing Player ID: 238 - Status: 200
# Processing Player ID: 235 - Status: 200
# Processing Player ID: 30 - Status: 200
# Processing Player ID: 28 - Status: 200
#
# Data saved to player_stats.csv
